# %% [markdown]
# ### generate ground truth file as json

# %%
#!pip install PyQt5

# %%
# generate Ground Truth as json from Oxford towncentre data


# input format
# generally as text, with ID & coordinates

# https://www.robots.ox.ac.uk/ActiveVision/Research/Projects/2009bbenfold_headpose/project.html
# The ground truth and tracking output is provided in the '.top' file format. 
# This consists of rows in comma-seperated variable (CSV) format:

# personNumber, frameNumber, headValid, bodyValid, headLeft, headTop, headRight, headBottom, 
#                         bodyLeft, bodyTop, bodyRight, bodyBottom

#personNumber - A unique identifier for the individual person
#frameNumber - The frame number (counted from 0)
#headValid - 1 if the head region is valid, 0 otherwise
#bodyValid - 1 if the body region is valid, 0 otherwise
#headLeft,headTop,headRight,headBottom - The head bounding box in pixels
#bodyLeft,bodyTop,bodyRight,bodyBottom - The body bounding box in pixels


# output format http://cocodataset.org/#format-data
{"info": 
 {"description": "COCO 2014 Dataset","url": "http://cocodataset.org","version": "1.0","year": 2014,
  "contributor": "COCO Consortium","date_created": "2017/09/01"},
 
 "images": 
 [
  {"license": 3,
   "file_name": "COCO_val2014_000000391895.jpg",
   "coco_url": "http://images.cocodataset.org/val2014/COCO_val2014_000000391895.jpg",
   "height": 360,"width": 640,
   "date_captured": "2013-11-14 11:18:45",
   "flickr_url": "http://farm9.staticflickr.com/8186/8119368305_4e622c8349_z.jpg",
   "id": 391895},
  {"license": 4,"file_name": "COCO_val2014_000000522418.jpg",
   "coco_url": "http://images.cocodataset.org/val2014/COCO_val2014_000000522418.jpg",
   "height": 480,"width": 640,"date_captured": "2013-11-14 11:38:44",
   "flickr_url": "http://farm1.staticflickr.com/1/127244861_ab0c0381e7_z.jpg",
   "id": 522418}
 ],
 
 "licenses": 
 [
  {"url": "http://creativecommons.org/licenses/by-nc-sa/2.0/","id": 1,"name": "Attribution-NonCommercial-ShareAlike License"},
  {"url": "http://creativecommons.org/licenses/by-nc/2.0/","id": 2,"name": "Attribution-NonCommercial License"},
  {"url": "http://creativecommons.org/licenses/by-nc-nd/2.0/","id": 3,"name": "Attribution-NonCommercial-NoDerivs License"},
  {"url": "http://creativecommons.org/licenses/by/2.0/","id": 4,"name": "Attribution License"},
  {"url": "http://creativecommons.org/licenses/by-sa/2.0/","id": 5,"name": "Attribution-ShareAlike License"},
  {"url": "http://creativecommons.org/licenses/by-nd/2.0/","id": 6,"name": "Attribution-NoDerivs License"},
  {"url": "http://flickr.com/commons/usage/","id": 7,"name": "No known copyright restrictions"},
  {"url": "http://www.usa.gov/copyright.shtml","id": 8,"name": "United States Government Work"}
 ],
 
 "annotations": 
 [
    {"segmentation": [[239.97,260.24,222.04,270.49,199.84,253.41,213.5,227.79,259.62,200.46,274.13,202.17,277.55,
                       210.71,249.37,253.41,237.41,264.51,242.54,261.95,228.87,271.34]], 
     "area": 2765.1486500000005, "iscrowd": 0,"image_id": 558840,"bbox": [199.84,200.46,77.71,70.88],
     "category_id": 58,"id": 156},
     {"segmentation": [[247.71,354.7,253.49,346.99,276.63,337.35,312.29,333.49,364.34,331.57,354.7,327.71,369.16,325.78,
                        376.87,333.49,383.61,330.6,379.76,321.93,365.3,320.0,356.63,317.11,266.02,331.57,260.24,334.46,
                                  17,410,19,409,19,5,11,393,36,392,37,391,38,390,38,390,38,390,38,390,38,390,38,390,38,390,38,390,39,389,40,388,41,388,40,389,39,391,37,392,36,
                                  393,35,323],
                       "size": [428,640]},"area": 28700,"iscrowd": 1,"image_id": 153344,"bbox": [1,29,638,398],"category_id": 1,"id": 900100153344},
],
 "categories": 
 [
     {"supercategory": "person","id": 1,"name": "person"},{"supercategory": "vehicle","id": 2,"name": "bicycle"},
     {"supercategory": "vehicle","id": 3,"name": "car"},{"supercategory": "vehicle","id": 4,"name": "motorcycle"},
     {"supercategory": "vehicle","id": 5,"name": "airplane"},{"supercategory": "vehicle","id": 6,"name": "bus"},
     {"supercategory": "vehicle","id": 7,"name": "train"},{"supercategory": "vehicle","id": 8,"name": "truck"},
     {"supercategory": "vehicle","id": 9,"name": "boat"},{"supercategory": "outdoor","id": 10,"name": "traffic light"},
     {"supercategory": "outdoor","id": 11,"name": "fire hydrant"},{"supercategory": "outdoor","id": 13,"name": "stop sign"},
     {"supercategory": "outdoor","id": 14,"name": "parking meter"},{"supercategory": "outdoor","id": 15,"name": "bench"},
     {"supercategory": "animal","id": 16,"name": "bird"},{"supercategory": "animal","id": 17,"name": "cat"},
     {"supercategory": "animal","id": 18,"name": "dog"},{"supercategory": "animal","id": 19,"name": "horse"},
     {"supercategory": "animal","id": 20,"name": "sheep"},{"supercategory": "animal","id": 21,"name": "cow"},
     {"supercategory": "animal","id": 22,"name": "elephant"},{"supercategory": "animal","id": 23,"name": "bear"},
     {"supercategory": "animal","id": 24,"name": "zebra"},{"supercategory": "animal","id": 25,"name": "giraffe"},
     {"supercategory": "accessory","id": 27,"name": "backpack"},{"supercategory": "accessory","id": 28,"name": "umbrella"},
     {"supercategory": "accessory","id": 31,"name": "handbag"},{"supercategory": "accessory","id": 32,"name": "tie"},
     {"supercategory": "accessory","id": 33,"name": "suitcase"},{"supercategory": "sports","id": 34,"name": "frisbee"},
     {"supercategory": "sports","id": 35,"name": "skis"},{"supercategory": "sports","id": 36,"name": "snowboard"},
     {"supercategory": "sports","id": 37,"name": "sports ball"},{"supercategory": "sports","id": 38,"name": "kite"},
     {"supercategory": "sports","id": 39,"name": "baseball bat"},{"supercategory": "sports","id": 40,"name": "baseball glove"},
     {"supercategory": "sports","id": 41,"name": "skateboard"},{"supercategory": "sports","id": 42,"name": "surfboard"},
     {"supercategory": "sports","id": 43,"name": "tennis racket"},{"supercategory": "kitchen","id": 44,"name": "bottle"},
     {"supercategory": "kitchen","id": 46,"name": "wine glass"},{"supercategory": "kitchen","id": 47,"name": "cup"},
     {"supercategory": "kitchen","id": 48,"name": "fork"},{"supercategory": "kitchen","id": 49,"name": "knife"},
     {"supercategory": "kitchen","id": 50,"name": "spoon"},{"supercategory": "kitchen","id": 51,"name": "bowl"},
     {"supercategory": "food","id": 52,"name": "banana"},{"supercategory": "food","id": 53,"name": "apple"},
     {"supercategory": "food","id": 54,"name": "sandwich"},{"supercategory": "food","id": 55,"name": "orange"},
     {"supercategory": "food","id": 56,"name": "broccoli"},{"supercategory": "food","id": 57,"name": "carrot"},
     {"supercategory": "food","id": 58,"name": "hot dog"},{"supercategory": "food","id": 59,"name": "pizza"},
     {"supercategory": "food","id": 60,"name": "donut"},{"supercategory": "food","id": 61,"name": "cake"},
     {"supercategory": "furniture","id": 62,"name": "chair"},{"supercategory": "furniture","id": 63,"name": "couch"},
     {"supercategory": "furniture","id": 64,"name": "potted plant"},{"supercategory": "furniture","id": 65,"name": "bed"},
     {"supercategory": "furniture","id": 67,"name": "dining table"},{"supercategory": "furniture","id": 70,"name": "toilet"},
     {"supercategory": "electronic","id": 72,"name": "tv"},{"supercategory": "electronic","id": 73,"name": "laptop"},
     {"supercategory": "electronic","id": 74,"name": "mouse"},{"supercategory": "electronic","id": 75,"name": "remote"},
     {"supercategory": "electronic","id": 76,"name": "keyboard"},{"supercategory": "electronic","id": 77,"name": "cell phone"},
     {"supercategory": "appliance","id": 78,"name": "microwave"},{"supercategory": "appliance","id": 79,"name": "oven"},
     {"supercategory": "appliance","id": 80,"name": "toaster"},{"supercategory": "appliance","id": 81,"name": "sink"},
     {"supercategory": "appliance","id": 82,"name": "refrigerator"},{"supercategory": "indoor","id": 84,"name": "book"},
     {"supercategory": "indoor","id": 85,"name": "clock"},{"supercategory": "indoor","id": 86,"name": "vase"},
     {"supercategory": "indoor","id": 87,"name": "scissors"},{"supercategory": "indoor","id": 88,"name": "teddy bear"},
     {"supercategory": "indoor","id": 89,"name": "hair drier"},{"supercategory": "indoor","id": 90,"name": "toothbrush"}
 ]
}

# %%
#import cv2
import pandas as pd
import numpy as np
from  matplotlib import pyplot as plt 
# %matplotlib qt
import json

# %%
import os
os.chdir("C:/Users/Desktop/data/")

# %%
# save the "TownCentre-groundtruth.top" as .csv file, & add column headers
df_groundtruth=pd.read_csv("TownCentre-groundtruth.csv")

# %%
df_groundtruth[df_groundtruth['frameNumber']==0]
# Out:
#     personNumber  frameNumber  headValid  bodyValid  headLeft   headTop  \
# 0              0            0          1          1   270.828   794.098
# 1              1            0          1          1   308.304   302.982
# 2              2            0          1          1   307.919   241.003
# 3              3            0          1          1   739.951   231.693
# 4              4            0          1          1   814.375   246.562
# 5              5            0          1          1   900.739   405.852
# 6              6            0          1          1   693.431  1028.397
# 7              7            0          1          1  1653.546   620.442
# 8              8            0          1          1  1666.107   923.010
# 9              9            0          1          1  1832.710   183.865
# 10            10            0          1          1  1676.228   122.099
# 11            11            0          1          1  1480.852    36.148
# ...

# %%
df_groundtruth = df_groundtruth[['frameNumber','bodyLeft','bodyTop','bodyRight', 'bodyBottom']]

# %%
# cols=['frame number','headLeft',' headRight',' bodyLeft',' bodyRight']
# df_groundtruth=df_groundtruth[cols]
df_groundtruth[df_groundtruth['frameNumber']==0]
# df_groundtruth.rename(columns={"headLeft": "xmin"," headRight":"xmax"," bodyLeft":"ymin"," bodyRight":"ymax"},inplace=True)
df_groundtruth.rename(columns={'bodyLeft':'xmin', 'bodyTop':'ymin','bodyRight':'xmax', 'bodyBottom':'ymax'},inplace=True)

# %%
df_groundtruth.tail(5)
# Out:
#        frameNumber      xmin     ymin      xmax     ymax
# 71455         4500   490.273  231.738   562.261  419.373
# 71456         4500  1555.319  506.651  1653.329  771.720
# 71457         4500  1144.991  518.861  1230.505  787.830
# 71458         4500   635.779  274.009   708.906  475.278
# 71459         4500  1362.262  128.042  1418.662  291.685

# %%
## add width & height columns; drop xmax & ymax
df_groundtruth['width'] = df_groundtruth['xmax'] - df_groundtruth['xmin']
df_groundtruth['height'] = df_groundtruth['ymax'] - df_groundtruth['ymin']
df_groundtruth.head(5)
# Out:
#    frameNumber     xmin     ymin     xmax      ymax    width   height
# 0            0  235.925  770.142  371.546  1101.029  135.621  330.887
# 1            0  285.748  291.418  370.556   493.414   84.808  201.996
# 2            0  286.849  230.501  365.794   416.410   78.945  185.909
# 3            0  719.708  220.830  786.893   408.145   67.185  187.315
# 4            0  793.722  235.410  861.430   427.627   67.708  192.217

# %%
df_groundtruth = df_groundtruth[['frameNumber','xmin','ymin','width', 'height']]
df_groundtruth.head(2)
# Out:
#    frameNumber     xmin     ymin    width   height
# 0            0  235.925  770.142  135.621  330.887
# 1            0  285.748  291.418   84.808  201.996

# %% [markdown]
# ## so the output json file should have xmin, ymin, width, height info of bbox

# %%
# create annotations json

# "annotations": [
#     {
#         "segmentation": [[510.66,423.01,511.72,420.03,...,510.45,423.01]],
#         "area": 702.1057499999998,
#         "iscrowd": 0,
#         "image_id": 289343,
#         "bbox": [473.07,395.93,38.65,28.67],
#         "category_id": 18,
#         "id": 1768
#     },

def frame_wise_indexes_GT(frame_number):
    df=df_groundtruth[df_groundtruth['frameNumber']==frame_number]
    return df

annotations=[]  
images=[]
coco_dict={}
id_counter=0

for i in range (0, df_groundtruth.tail(1).loc[:,'frameNumber'].values[0] + 1):
    df= frame_wise_indexes_GT(i)
    temp_image_dict = {
        'id':int(i),
        'license':7,
        'coco_url':'',
        'flickr_url':'',
        'width':int(1920),
        'height':int(1080),
        'filename':str(i) + ".jpg", #int(i),  #"D:\\Social Distancing WIP\\vid_to_img\\frame"+str(i)+".jpg" ,
        'date_captures':''
    }
    images.append(temp_image_dict)
    #j=0
    for row in df.iterrows():
        res=dict()
        res['segmentation']=[[]]   #### CHANGE HERE
        res['area']=row[1][3]*row[1][4]  #float(0)       #### CHANGE HERE
        res['image_id']=int(i)
        #res['bbox']=[row[1][1],row[1][2],row[1][3],row[1][4]]
        res['bbox']=['%.3f'%row[1][1],'%.3f'%row[1][2],'%.3f'%row[1][3],'%.3f'%row[1][4]]
        res['category_id']=int(1)   #### CHANGED HERE FROM 1
        res['id']=int(id_counter)  #int(j)
        res["iscrowd"]=0
        #j+=1
        id_counter+=1
        annotations.append(res)
        

info = {"description": "towncentre Dataset","url": "","version": "1.0","year": 2014,"contributor": "","date_created": "2017/09/01"}
coco_dict['info'] = info

coco_dict['images'] = images

coco_dict['licenses'] = [{"url": "http://flickr.com/commons/usage/","id": 7,"name": "No known copyright restrictions"}]

coco_dict['annotations'] = annotations

#categories= [{"supercategory": "person","id": 1,"name": "person"}]  #### CHANGED id from 1 to 0
#categories= {"supercategory": "person","id": 1,"name": "person"}
categories = [{"supercategory": "person","id": 1,"name": "person"},{"supercategory": "vehicle","id": 2,"name": "bicycle"},
     {"supercategory": "vehicle","id": 3,"name": "car"},{"supercategory": "vehicle","id": 4,"name": "motorcycle"},
     {"supercategory": "vehicle","id": 5,"name": "airplane"},{"supercategory": "vehicle","id": 6,"name": "bus"},
     {"supercategory": "vehicle","id": 7,"name": "train"},{"supercategory": "vehicle","id": 8,"name": "truck"},
     {"supercategory": "vehicle","id": 9,"name": "boat"},{"supercategory": "outdoor","id": 10,"name": "traffic light"},
     {"supercategory": "outdoor","id": 11,"name": "fire hydrant"},{"supercategory": "outdoor","id": 13,"name": "stop sign"},
     {"supercategory": "outdoor","id": 14,"name": "parking meter"},{"supercategory": "outdoor","id": 15,"name": "bench"},
     {"supercategory": "animal","id": 16,"name": "bird"},{"supercategory": "animal","id": 17,"name": "cat"},
     {"supercategory": "animal","id": 18,"name": "dog"},{"supercategory": "animal","id": 19,"name": "horse"},
     {"supercategory": "animal","id": 20,"name": "sheep"},{"supercategory": "animal","id": 21,"name": "cow"},
     {"supercategory": "animal","id": 22,"name": "elephant"},{"supercategory": "animal","id": 23,"name": "bear"},
     {"supercategory": "animal","id": 24,"name": "zebra"},{"supercategory": "animal","id": 25,"name": "giraffe"},
     {"supercategory": "accessory","id": 27,"name": "backpack"},{"supercategory": "accessory","id": 28,"name": "umbrella"},
     {"supercategory": "accessory","id": 31,"name": "handbag"},{"supercategory": "accessory","id": 32,"name": "tie"},
     {"supercategory": "accessory","id": 33,"name": "suitcase"},{"supercategory": "sports","id": 34,"name": "frisbee"},
     {"supercategory": "sports","id": 35,"name": "skis"},{"supercategory": "sports","id": 36,"name": "snowboard"},
     {"supercategory": "sports","id": 37,"name": "sports ball"},{"supercategory": "sports","id": 38,"name": "kite"},
     {"supercategory": "sports","id": 39,"name": "baseball bat"},{"supercategory": "sports","id": 40,"name": "baseball glove"},
     {"supercategory": "sports","id": 41,"name": "skateboard"},{"supercategory": "sports","id": 42,"name": "surfboard"},
     {"supercategory": "sports","id": 43,"name": "tennis racket"},{"supercategory": "kitchen","id": 44,"name": "bottle"},
     {"supercategory": "kitchen","id": 46,"name": "wine glass"},{"supercategory": "kitchen","id": 47,"name": "cup"},
     {"supercategory": "kitchen","id": 48,"name": "fork"},{"supercategory": "kitchen","id": 49,"name": "knife"},
     {"supercategory": "kitchen","id": 50,"name": "spoon"},{"supercategory": "kitchen","id": 51,"name": "bowl"},
     {"supercategory": "food","id": 52,"name": "banana"},{"supercategory": "food","id": 53,"name": "apple"},
     {"supercategory": "food","id": 54,"name": "sandwich"},{"supercategory": "food","id": 55,"name": "orange"},
     {"supercategory": "food","id": 56,"name": "broccoli"},{"supercategory": "food","id": 57,"name": "carrot"},
     {"supercategory": "food","id": 58,"name": "hot dog"},{"supercategory": "food","id": 59,"name": "pizza"},
     {"supercategory": "food","id": 60,"name": "donut"},{"supercategory": "food","id": 61,"name": "cake"},
     {"supercategory": "furniture","id": 62,"name": "chair"},{"supercategory": "furniture","id": 63,"name": "couch"},
     {"supercategory": "furniture","id": 64,"name": "potted plant"},{"supercategory": "furniture","id": 65,"name": "bed"},
     {"supercategory": "furniture","id": 67,"name": "dining table"},{"supercategory": "furniture","id": 70,"name": "toilet"},
     {"supercategory": "electronic","id": 72,"name": "tv"},{"supercategory": "electronic","id": 73,"name": "laptop"},
     {"supercategory": "electronic","id": 74,"name": "mouse"},{"supercategory": "electronic","id": 75,"name": "remote"},
     {"supercategory": "electronic","id": 76,"name": "keyboard"},{"supercategory": "electronic","id": 77,"name": "cell phone"},
     {"supercategory": "appliance","id": 78,"name": "microwave"},{"supercategory": "appliance","id": 79,"name": "oven"},
     {"supercategory": "appliance","id": 80,"name": "toaster"},{"supercategory": "appliance","id": 81,"name": "sink"},
     {"supercategory": "appliance","id": 82,"name": "refrigerator"},{"supercategory": "indoor","id": 84,"name": "book"},
     {"supercategory": "indoor","id": 85,"name": "clock"},{"supercategory": "indoor","id": 86,"name": "vase"},
     {"supercategory": "indoor","id": 87,"name": "scissors"},{"supercategory": "indoor","id": 88,"name": "teddy bear"},
     {"supercategory": "indoor","id": 89,"name": "hair drier"},{"supercategory": "indoor","id": 90,"name": "toothbrush"}
 ]
coco_dict['categories']=categories

# %%
coco_dict
# Out:
# {'info': {'description': 'towncentre Dataset',
#   'url': '',
#   'version': '1.0',
#   'year': 2014,
#   'contributor': '',
#   'date_created': '2017/09/01'},
#  'images': [{'id': 0,
#    'license': 7,
#    'coco_url': '',
#    'flickr_url': '',
#    'width': 1920,
#    'height': 1080,
#    'filename': '0.jpg',
#    'date_captures': ''},
#   {'id': 1,
#    'license': 7,
#    'coco_url': '',
#    'flickr_url': '',
#    'width': 1920,
#    'height': 1080,
#    'filename': '1.jpg',
#    'date_captures': ''},
#   {'id': 2,
#    'license': 7,
#    'coco_url': '',
#    'flickr_url': '',
#    'width': 1920,
#    'height': 1080,
#    'filename': '2.jpg',
#    'date_captures': ''},
#   {'id': 3,
#    'license': 7,
#    'coco_url': '',
#    'flickr_url': '',
#    'width': 1920,
#    'height': 1080,
#    'filename': '3.jpg',
#    'date_captures': ''},
#   {'id': 4,
#    'license': 7,
#    'coco_url': '',
#    'flickr_url': '',
#    'width': 1920,
#    'height': 1080,
#    'filename': '4.jpg',
# ...

# %%
import json 
with open('instances_towncentre.json', 'w') as f:
#with open('towncentre_groundtruth.json', 'w') as f:
    json.dump(coco_dict, f,  separators=(',', ': '))

# %% [markdown]
# ###### create towncentre ground truth files as text files, for each separate image

# %%
#import os
gt = 'groundtruth_txt'
os.mkdir(gt)

# %%
def frame_wise_indexes_GT(frame_number):
    df=df_groundtruth[df_groundtruth['frameNumber']==frame_number]
    return df

for j in range(4501): #4501  # 2
    #df = pd.DataFrame()
    #df = df_groundtruth[df_groundtruth['frameNumber']==j]
    df= frame_wise_indexes_GT(j)
    
    out_txt = "./groundtruth_txt/" + str(j) + '.txt'
    outj = open(out_txt, 'a')
    
    for row in df.iterrows():
        #ss = str(0) +' '+ str('%.3f'%row[1][1]) +' '+ str('%.3f'%row[1][2]) +' '+ str('%.3f'%row[1][3]) +' '+ str('%.3f'%row[1][4]) + "\n"
        ss = str(0) +' '+ str(int(row[1][1])) +' '+ str(int(row[1][2])) +' '+ str(int(row[1][3])) +' '+ str(int(row[1][4])) + "\n"
        outj.write(ss)
    
    outj.close()
